# %% [markdown]
# <a href="https://colab.research.google.com/github/krystaldowling/MAST30034_Final_Project-/blob/master/test_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = "/content/drive/My Drive/Data/"

# %%
import pandas as pd

# %%
data = pd.read_csv(PATH + 'fake.csv')

# %%
data.head(10)
# Out:
#                                        uuid  ord_in_thread  ... shares  type
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0  ...      0  bias
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0  ...      0  bias
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3              0  ...      0  bias
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284              0  ...      0  bias
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f              0  ...      0  bias
# 5  8f30f5ea14c9d5914a9fe4f55ab2581772af4c31              0  ...      0  bias
# 6  d3cc0fe38f41a59f7c48f8c3528ca5f74193148f              0  ...      0  bias
# 7  b4bbf8b5c19e8864f5257832a58b81ef4ed2d4e4              0  ...      0  bias
# 8  a19aabaa5a61eb8bc22fadaaa003e5fbba5c4bf6              0  ...      0  bias
# 9  f54d8e13010d0a79893995ee65360ad4b38b5a35              0  ...      0  bias
#
# [10 rows x 20 columns]
